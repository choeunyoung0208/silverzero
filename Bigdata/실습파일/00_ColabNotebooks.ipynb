# %% [markdown]
# # Colab으로 파이썬 시작하기

# %%
print(1) # ctrl + enter
# Out:
# 1

# %%
1 + 5 # shift + enter : 실행 후, 아래 셀로 이동
# Out:
# 6

# %%
1 + 5
4 + 6 # alt + enter : 실행 후, 아래 셀을 추가 : 알을 낳는다.
# Out:
# 10

# %%
1 + 2
3 + 4
5 + 7
# Out:
# 12

# %%
# ctrl + M : 기본 -> 주석처리 : 코드 셀 안에서 코드에 포함시키고 싶지 않은 부분

# %% [markdown]
# 코드 셀 -> 마크다운 셀 : 기본 단축키 + M
# 마크다운 셀 -> 코드 셀 : 기본 단축키 + Y (why?)

# %% [markdown]
# 셀 삭제 : 기본 + D
# 셀 추가 : 기본 + A (Above, 위) / 기본 + B (Below, 아래)

# %% [markdown]
# # 타이틀
# ## 서브타이틀
# ### 서브타이틀2
# #### 서브타이틀3
# - 세부 설명
# * 세부설명 2
# 파이썬은 재밌다
# 파이썬 공부하고 싶다
#
# **마크다운에서 줄바꿈은 스페이스 두번이다.**
